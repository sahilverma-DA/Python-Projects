# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
dataset = pd.read_csv('E:\Datasets\car_price_prediction.csv')

# %%
dataset.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# ...

# %%
dataset.isnull().sum()
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19237 non-null  object
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19237 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
# ...

# %%
Model_le = LabelEncoder()
dataset['Model'] = Model_le.fit_transform(dataset['Model'])

# %%
dataset.head(2)
# Out:
#          ID  Price  Levy Manufacturer  Model  Prod. year Category  \
# 0  45654403  13328  1399        LEXUS   1242        2010     Jeep
# 1  44731507  16621  1018    CHEVROLET    658        2011     Jeep
#
#   Leather interior  Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes          2           3.5  186005 km        6.0
# 1               No          5             3  192000 km        6.0
#
#   Gear box type Drive wheels   Doors       Wheel   Color  Airbags
# 0     Automatic          4x4  04-May  Left wheel  Silver       12
# 1     Tiptronic          4x4  04-May  Left wheel   Black        8

# %%
dataset['Fuel type'].unique()
# Out:
# array(['Hybrid', 'Petrol', 'Diesel', 'CNG', 'Plug-in Hybrid', 'LPG',
#        'Hydrogen'], dtype=object)

# %%
Fuel_type_le = LabelEncoder()
dataset['Fuel type'] = Fuel_type_le.fit_transform(dataset['Fuel type'])

# %%
dataset.head()
# Out:
#          ID  Price  Levy Manufacturer  Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   1242        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET    658        2011       Jeep
# 2  45774419   8467     -        HONDA    684        2006  Hatchback
# 3  45769185   3607   862         FORD    661        2011       Jeep
# 4  45809263  11726   446        HONDA    684        2014  Hatchback
#
#    Fuel type Engine volume  Cylinders             Wheel  Airbags
# 0          2           3.5        6.0        Left wheel       12
# 1          5             3        6.0        Left wheel        8
# 2          5           1.3        4.0  Right-hand drive        2
# 3          2           2.5        4.0        Left wheel        0
# 4          5           1.3        4.0        Left wheel        4

# %%
Manufacturer_le = LabelEncoder()
dataset['Manufacturer'] = Manufacturer_le.fit_transform(dataset['Manufacturer'])

# %%
Cylinders_le = LabelEncoder()
dataset['Cylinders'] = Cylinders_le.fit_transform(dataset['Cylinders'])

# %%
Wheel_le = LabelEncoder()
dataset['Wheel'] = Wheel_le.fit_transform(dataset['Wheel'])

# %%
Category_le = LabelEncoder()
dataset['Category'] = Category_le.fit_transform(dataset['Category'])

# %%
dataset.head()
# Out:
#          ID  Price  Levy  Manufacturer  Model  Prod. year  Category  \
# 0  45654403  13328  1399            32   1242        2010         4
# 1  44731507  16621  1018             8    658        2011         4
# 2  45774419   8467     -            21    684        2006         3
# 3  45769185   3607   862            16    661        2011         4
# 4  45809263  11726   446            21    684        2014         3
#
#    Fuel type Engine volume  Cylinders  Wheel  Airbags
# 0          2           3.5          5      0       12
# 1          5             3          5      0        8
# 2          5           1.3          3      1        2
# 3          2           2.5          3      0        0
# 4          5           1.3          3      0        4

# %%
output_data = dataset['Price']
input_data = dataset.drop(columns=['Price','Levy','Engine volume'])

# %%
input_data.head()
# Out:
#          ID  Manufacturer  Model  Prod. year  Category  Fuel type  Cylinders  \
# 0  45654403            32   1242        2010         4          2          5
# 1  44731507             8    658        2011         4          5          5
# 2  45774419            21    684        2006         3          5          3
# 3  45769185            16    661        2011         4          2          3
# 4  45809263            21    684        2014         3          5          3
#
#    Wheel  Airbags
# 0      0       12
# 1      0        8
# 2      1        2
# 3      0        0
# 4      0        4

# %%
from sklearn.preprocessing import StandardScaler

# %%
input_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             19237 non-null  int64
#  1   Levy           19237 non-null  object
#  2   Manufacturer   19237 non-null  int32
#  3   Model          19237 non-null  int32
#  4   Prod. year     19237 non-null  int64
#  5   Category       19237 non-null  int32
#  6   Fuel type      19237 non-null  int32
#  7   Engine volume  19237 non-null  object
#  8   Cylinders      19237 non-null  int64
#  9   Wheel          19237 non-null  int32
#  10  Airbags        19237 non-null  int64
# dtypes: int32(5), int64(4), object(2)
# memory usage: 1.2+ MB

# %%
ss = StandardScaler()
input_data = pd.DataFrame(ss.fit_transform(input_data),columns=input_data.columns)

# %%
input_data
# Out:
#              ID  Manufacturer     Model  Prod. year  Category  Fuel type  \
# 0      0.083141     -0.060828  0.923579   -0.161034 -0.811892  -0.792543
# 1     -0.902262     -1.411723 -0.498032    0.015379 -0.811892   0.867354
# 2      0.211286     -0.679989 -0.434741   -0.866685 -1.170251   0.867354
# 3      0.205697     -0.961425 -0.490729    0.015379 -0.811892  -0.792543
# 4      0.248490     -0.679989 -0.434741    0.544617 -1.170251   0.867354
# ...         ...           ...       ...         ...       ...        ...
# 19232  0.236843      0.164321 -1.162586   -2.101574 -1.886969  -1.899141
# 19233  0.216023     -0.567414  1.147531    0.015379  0.979903   0.867354
# 19234  0.243935     -0.567414  1.410432   -0.161034 -0.811892  -1.345842
# 19235  0.231687     -1.411723 -0.989754   -0.690272 -0.811892  -1.345842
# 19236  0.252771     -0.567414  1.147531    0.191792  0.979903  -0.792543
#
#        Cylinders     Wheel   Airbags
# 0       1.202064 -0.289122  1.254005
# ...
